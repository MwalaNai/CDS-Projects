# %% [markdown]
# ### Problem Statement
#
# Use relevant ML Model to predict total sales using features like money spent on Advertising/Marketing
# individual fields.

# %% [markdown]
# ### import basic libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### load dataset

# %%
data = pd.read_csv("Advertising.csv")

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
# drop the unnamed column
data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Domain Analyis
# * Sales is target
# *TV , Radio , and Newspaper are input variables
# *This data basically tells us about the total sales made by the company by investing certain amount of money on TV ,Radio and Newspaper Advertising.

# %% [markdown]
# ### Basic Checks

# %%
# shape
data.shape
# Out:
# (200, 4)

# %%
# print all coulmn
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
# types
data.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
# head
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# tail
data.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
# info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
# describe
data.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# Radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# Newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# Sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %% [markdown]
# ### Insights
#
# *Average sales made by the company is 14.02m$
#
# *Average amount spent on TV is more compared to Radio and Newspaper
# *Maximum amount spent on TV advertising is more compared to Radio and Newspaper

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ###  Expolratory Data Analysis

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
# * Analyze single variable /column/feature
# * check the distribution of each column

# %%
# check the distribution of TV
sns.distplot(x=data.TV,kde=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# check the distribution of Radio
sns.distplot(x=data.Radio,kde=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# check the distribution of Newspaper
sns.distplot(x=data.Newspaper,kde=True)
# Out:
# <Axes: ylabel='Density'>

# %%
# check the distribution of Sales
sns.distplot(x=data.Sales,kde=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Insights
# * Only Sales is representing normal distribution

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Analysing multiple variables

# %%
# Analyse how amount spent on TV impact Sales
sns.scatterplot(data=data,x='TV',y='Sales')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %% [markdown]
# ### Insights
# * as we increase the amount of money spent on TV AND advertisning then sales will increase.
# * There is a high correlation between TV and Sales
# * There is a positive relationship between TV and Sales.

# %%
# Analyse how amount spent on Radio impact Sales
sns.scatterplot(data=data,x='Radio',y='Sales')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %% [markdown]
# ### Insights
# * as we increase the amount of money spent on TV AND advertisning then sales will increase.
# * There is a high correlation between TV and Sales
# * There is a positive relationship between TV and Sales.

# %%
# Analyse how amount spent on TV impact Sales
sns.scatterplot(data=data,x='Newspaper',y='Sales')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %% [markdown]
# #### Multivariate Analysis
