# %% [markdown]
# #                                    Exploratory Data Analysis Using Pandas

# %% [markdown]
# #### Dataset : https://www.kaggle.com/utkarsharya/ecommerce-purchases

# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %% [markdown]
# ### Import the Dataset

# %%
data = pd.read_csv('C:/Ecommerce Purchases.csv')

# %% [markdown]
# ### Previewing Data

# %%
data
# Out:
#                              Address              Lot AM or PM  \
# 0          "16629 Pace Camp Apt. 448              NaN      NaN
# 1                      Alexisborough   NE 77130-7478"    46 in
# 2      "9374 Jasmine Spurs Suite 508              NaN      NaN
# 3                         South John   TN 84355-4179"    28 rn
# 4                "Unit 0065 Box 5052              NaN      NaN
# ...                              ...              ...      ...
# 19995             DPO AE 28026-0283"            74 Zh       AM
# 19996             "0096 English Rest              NaN      NaN
# 19997                        Roystad        IA 12457"    74 cL
# 19998       "40674 Barrett Stravenue              NaN      NaN
# 19999                    Grimesville        WI 79682"    64 Hr
#
#                                             Browser Info  \
# 0                                                    NaN
# 1                                                     PM
# ...

# %% [markdown]
# ### 1. Display Top 10 Rows of the Dataset

# %%
data.head(10)
# Out:
#                          Address              Lot AM or PM  \
# 0      "16629 Pace Camp Apt. 448              NaN      NaN
# 1                  Alexisborough   NE 77130-7478"    46 in
# 2  "9374 Jasmine Spurs Suite 508              NaN      NaN
# 3                     South John   TN 84355-4179"    28 rn
# 4            "Unit 0065 Box 5052              NaN      NaN
# 5                  DPO AP 27450"            94 vE       PM
# 6              "7780 Julia Fords              NaN      NaN
# 7                      New Stacy        WA 45798"    36 vm
# 8   "23012 Munoz Drive Suite 337              NaN      NaN
# 9                    New Cynthia        TX 57826"    20 IE
#
#                                         Browser Info  \
# 0                                                NaN
# 1                                                 PM
# 2                                                NaN
# 3                                                 PM
# ...

# %% [markdown]
# ### 2. Check the last 10 rows

# %%
data.tail(10)
# Out:
#                          Address         Lot AM or PM  \
# 19990       "966 Castaneda Locks         NaN      NaN
# 19991             West Juliafurt   CO 96415"    92 XI
# 19992  "832 Curtis Dam Suite 785         NaN      NaN
# 19993          North Edwardburgh   TX 55158"    41 JY
# 19994        "Unit 4434 Box 6343         NaN      NaN
# 19995         DPO AE 28026-0283"       74 Zh       AM
# 19996         "0096 English Rest         NaN      NaN
# 19997                    Roystad   IA 12457"    74 cL
# 19998   "40674 Barrett Stravenue         NaN      NaN
# 19999                Grimesville   WI 79682"    64 Hr
#
#                                             Browser Info  \
# 19990                                                NaN
# 19991                                                 PM
# 19992                                                NaN
# 19993                                                 AM
# 19994                                                NaN
# ...

# %% [markdown]
# ### 3. Check the Data type for each Column

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card          object
# CC Exp Date          object
# CC Security Code     object
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price       object
# Unnamed: 14          object
# Unnamed: 15          object
# Unnamed: 16          object
# Unnamed: 17         float64
# dtype: object

# %% [markdown]
# ### 4. Check for Null values in the Dataset

# %%
data.isnull().sum()
# Out:
# Address                 0
# Lot                  9656
# AM or PM            10000
# Browser Info        10000
# Company             10000
# Credit Card         10000
# CC Exp Date         10000
# CC Security Code    10000
# CC Provider         10000
# Email               10000
# Job                 10000
# IP Address          10000
# Language            10000
# Purchase Price      10000
# Unnamed: 14         10272
# Unnamed: 15         13426
# Unnamed: 16         17734
# Unnamed: 17         19717
# dtype: int64

# %% [markdown]
# ## I have to work on the csv file to fix the issues of missing values
# ## rearrange the values

# %%
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17'],
#       dtype='object')

# %%
data["Unnamed: 15"]
# Out:
# 0          NaN
# 1        98.14
# 2          NaN
# 3        70.73
# 4          NaN
#          ...
# 19995      NaN
# 19996      NaN
# 19997      NaN
# 19998      NaN
# 19999    67.59
# Name: Unnamed: 15, Length: 20000, dtype: object
